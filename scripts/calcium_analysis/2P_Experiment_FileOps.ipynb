# %%
from pathlib import Path
import shutil
from typing import Iterable, Tuple
import shutil, os

# %%
# Prints the relative paths under root up to max_depth.
#Use this to sanity-check that renames/moves produced the expected structure.
root = Path(r"C:\Users\suribear\OneDrive - Université de Lausanne\Lab\Data\2p\L453_f10_Exp_1_flickering")
max_depth = 3
# change this to show deeper levels

for p in root.rglob("*"):
    depth = len(p.relative_to(root).parts)
    if depth <= max_depth:
        print(p.relative_to(root))

# %%
# Helpers to copy only 03_analysis from each experiment
# \
# Defines:
# find_experiments_with_analysis(src_root): yields experiments that contain a 03_analysis folder.
# copy_analysis_only(...): copies each experiment’s 03_analysis into the destination, with:
# dry_run=True → prints what it would do (no copy)
# overwrite=True → removes an existing destination 03_analysis before copying
# Returns a tuple: (n_experiments_found, n_operations_{planned|done}).

def find_experiments_with_analysis(src_root: Path) -> Iterable[Path]:
    """
    Yield experiment directories under src_root that contain a '03_analysis' subfolder.
    """
    for p in src_root.iterdir():
        if p.is_dir() and (p / "03_analysis").exists():
            yield p


def copy_analysis_only(
        src_root: Path,
        dst_root: Path,
        exp_glob: str = "*",  # pattern to match experiment folder names, e.g. "L4*_Exp_*"
        dry_run: bool = True,  # True = preview; False = actually copy
        overwrite: bool = False,  # True = allow overwriting an existing destination
) -> Tuple[int, int]:
    """
    Copy only the '03_analysis' folder for each experiment folder from src_root to dst_root.

    Layout copied:
      dst_root/<experiment_name>/03_analysis/<...contents...>

    Returns (n_experiments, n_operations_planned).
    """
    src_root = Path(src_root)
    dst_root = Path(dst_root)
    assert src_root.exists(), f"Source root does not exist: {src_root}"

    exps = [p for p in find_experiments_with_analysis(src_root) if p.match(exp_glob)]
    if not exps:
        print("No experiment folders with '03_analysis' found matching pattern.")
        return 0, 0

    ops = 0
    for exp_dir in exps:
        src_analysis = exp_dir / "03_analysis"
        dst_exp = dst_root / exp_dir.name
        dst_analysis = dst_exp / "03_analysis"

        # Plan: create <dst_exp>, then copytree 03_analysis → dst_analysis
        print(f"\n[EXP] {exp_dir.name}")
        print(f"  SRC: {src_analysis}")
        print(f"  DST: {dst_analysis}")

        if dry_run:
            if dst_analysis.exists():
                action = "would OVERWRITE" if overwrite else "would SKIP (exists)"
            else:
                action = "would COPY"
            print(f"  Action (dry-run): {action}")
            ops += 1
            continue

        # Actual copy
        dst_exp.mkdir(parents=True, exist_ok=True)
        if dst_analysis.exists():
            if overwrite:
                print("  Removing existing destination (overwrite=True)...")
                shutil.rmtree(dst_analysis)
            else:
                print("  Destination exists and overwrite=False; skipping.")
                continue

        print("  Copying...")
        shutil.copytree(src_analysis, dst_analysis)  # copies full subtree
        ops += 1

    print(f"\nDone. Experiments found: {len(exps)} | Operations {'planned' if dry_run else 'done'}: {ops}")
    return len(exps), ops

# %%
#copy_analysis_only from network to local

# copy_analysis_only from network to local

# Example: preview first, then optionally execute the 03_analysis copy.
#  1) Leave dry_run=True to print the planned actions without copying files.
#  2) After checking the paths, use the commented execute block with dry_run=False.
# overwrite=False keeps any existing destination; set True only if you want to replace it.
# Set your source and destination roots (Windows UNC / mapped drive paths).

src_root = Path(r"\\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro")
dst_root = Path(r"D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p")  # <-- choose where to copy

# 1) Preview (no files copied)
copy_analysis_only(
    src_root=src_root,
    dst_root=dst_root,
    exp_glob="L800_f08",  # or e.g. "L4*_Exp_*" to limit which experiments
    dry_run=False,  # preview only
    overwrite=True,
)
# # 2) Execute copy only after the preview output looks correct
# copy_analysis_only(
#     src_root=src_root,
#     dst_root=dst_root,
#     exp_glob="*",  # same pattern you previewed
#     dry_run=False,  # actually copy
#     overwrite=False,  # set True if you want to replace existing destinations
# )
# Out:
# [EXP] L800_f08
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f08\03_analysis
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f08\03_analysis
#   Removing existing destination (overwrite=True)...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[16], line 15
#      12 dst_root = Path(r"D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p")  # <-- choose where to copy
#      14 # 1) Preview (no files copied)
# ---> 15 copy_analysis_only(
#      16     src_root=src_root,
#      17     dst_root=dst_root,
#      18     exp_glob="L800_f08",  # or e.g. "L4*_Exp_*" to limit which experiments
#      19     dry_run=False,  # preview only
#      20     overwrite=True,
#      21 )
#
# Cell In[9], line 68, in copy_analysis_only(src_root, dst_root, exp_glob, dry_run, overwrite)
#      66 if overwrite:
#      67     print("  Removing existing destination (overwrite=True)...")
# ---> 68     shutil.rmtree(dst_analysis)
#      69 else:
#      70     print("  Destination exists and overwrite=False; skipping.")
#
# File c:\ProgramData\miniconda3\envs\social_filters\Lib\shutil.py:787, in rmtree(path, ignore_errors, onerror, dir_fd)
#     785     # can't continue even if onerror hook returns
#     786     return
# --> 787 return _rmtree_unsafe(path, onerror)
#
# File c:\ProgramData\miniconda3\envs\social_filters\Lib\shutil.py:629, in _rmtree_unsafe(path, onerror)
#     627         onerror(os.path.islink, fullname, sys.exc_info())
#     628         continue
# --> 629     _rmtree_unsafe(fullname, onerror)
#     630 else:
#     631     try:
#
# File c:\ProgramData\miniconda3\envs\social_filters\Lib\shutil.py:629, in _rmtree_unsafe(path, onerror)
#     627         onerror(os.path.islink, fullname, sys.exc_info())
#     628         continue
# --> 629     _rmtree_unsafe(fullname, onerror)
#     630 else:
#     631     try:
#
# File c:\ProgramData\miniconda3\envs\social_filters\Lib\shutil.py:638, in _rmtree_unsafe(path, onerror)
#     636     os.rmdir(path)
#     637 except OSError:
# --> 638     onerror(os.rmdir, path, sys.exc_info())
#
# File c:\ProgramData\miniconda3\envs\social_filters\Lib\shutil.py:636, in _rmtree_unsafe(path, onerror)
#     634             onerror(os.unlink, fullname, sys.exc_info())
#     635 try:
# --> 636     os.rmdir(path)
#     637 except OSError:
#     638     onerror(os.rmdir, path, sys.exc_info())
#
# PermissionError: [WinError 5] Access is denied: 'D:\\Alejandro\\Data\\OneDrive - Université de Lausanne\\Lab\\Data\\2p\\L800_f08\\03_analysis\\functional\\suite2P'

# %%
# Scratch-only network path check.
# This is only for ad hoc debugging and can be deleted later.
# Uncomment the lines below only if you need to verify that the source path is reachable.
# src_root = Path(r"\\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro")
# print("Exists:", src_root.exists())

# %%
#copy_metadata from network to local

# Function to copy only 01_raw/2p/metadata/**

# Defines copy_metadata_only(...):

# Finds experiments in src_root matching exp_glob.
# If dry_run=True, prints the action it would take.
# If executing, recreates the internal folder structure and copies files into …/01_raw/2p/metadata.
# Respects overwrite: if False, existing files are left as-is.

def copy_metadata_only(
    src_root: Path,
    dst_root: Path,
    exp_glob: str = "*",
    dry_run: bool = True,
    overwrite: bool = False,
):
    """
    Copy only 01_raw/2p/metadata/** for experiments that contain it.
    """
    src_root = Path(src_root); dst_root = Path(dst_root)
    exps = [p for p in src_root.iterdir() if p.is_dir() and p.match(exp_glob)]
    ops = 0
    for exp_dir in exps:
        src_meta = exp_dir / "01_raw" / "2p" / "metadata"
        if not src_meta.exists():
            continue
        dst_meta = dst_root / exp_dir.name / "01_raw" / "2p" / "metadata"
        print(f"\n[EXP] {exp_dir.name}")
        print(f"  SRC: {src_meta}")
        print(f"  DST: {dst_meta}")
        if dry_run:
            if dst_meta.exists():
                action = "would MERGE CONTENTS" if not overwrite else "would OVERWRITE CONTENTS"
            else:
                action = "would COPY CONTENTS"
            print(f"  Action (dry-run): {action}")
            ops += 1
        else:
            dst_meta.mkdir(parents=True, exist_ok=True)
            for root, _, files in os.walk(src_meta):
                rel = Path(root).relative_to(src_meta)
                here = dst_meta / rel
                here.mkdir(parents=True, exist_ok=True)
                for f in files:
                    s = Path(root) / f
                    d = here / f
                    if d.exists() and not overwrite:
                        continue
                    shutil.copy2(s, d)
            ops += 1
    print(f"\nDone. Operations {'planned' if dry_run else 'done'}: {ops}")

# %%
# Example: preview first, then optionally execute the metadata copy

# Calls copy_metadata_only(...) with your src_root/dst_root.
#  1) Leave dry_run=True to print the planned actions without copying files.
#  2) Change to dry_run=False only when you are ready to copy.
# overwrite=False prevents replacing existing files; set to True only if you need to refresh them.

src_root = Path(r"\\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro")
dst_root = Path(r"D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p")

# Preview only (prints what it will do; copies nothing)
copy_metadata_only(
    src_root=src_root,
    dst_root=dst_root,
    exp_glob="L800*",   # pattern for experiment folder names (use "*" for all)
    dry_run=False,    # preview only
    overwrite=False  # don't replace files if they already exist in dst
)
# Out:
# [EXP] L800_f02
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f02\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f02\01_raw\2p\metadata
#
# [EXP] L800_f03
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f03\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f03\01_raw\2p\metadata
#
# [EXP] L800_f08
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f08\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f08\01_raw\2p\metadata
#
# [EXP] L800_f11
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f11\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f11\01_raw\2p\metadata
#
# [EXP] L800_f07
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f07\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f07\01_raw\2p\metadata
#
# [EXP] L800_f10
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f10\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f10\01_raw\2p\metadata
#
# [EXP] L800_f04
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f04\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f04\01_raw\2p\metadata
#
# [EXP] L800_f09
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f09\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f09\01_raw\2p\metadata
#
# [EXP] L800_f01
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f01\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f01\01_raw\2p\metadata
#
# [EXP] L800_f05
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f05\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f05\01_raw\2p\metadata
#
# [EXP] L800_f06
#   SRC: \\nasdcsr.unil.ch\RECHERCHE\FAC\FBM\CIG\jlarsch\default\D2c\07_Data\Alejandro\L800_f06\01_raw\2p\metadata
#   DST: D:\Alejandro\Data\OneDrive - Université de Lausanne\Lab\Data\2p\L800_f06\01_raw\2p\metadata
#
# Done. Operations done: 11
